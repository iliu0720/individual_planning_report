# %% [raw]
# Individaul Planning Report

# %% [raw]
# Ivan Liu     #28950673

# %% [raw]
# (1) Data Description

# %%
### Run this cell before continuing.
library(tidyverse)
library(repr)
library(tidymodels)
library(cowplot)
options(repr.matrix.max.rows = 6)
source('cleanup.R')

# %%
players = read_csv("players.csv")
sessions = read_csv("sessions.csv")
# Out:
# Rows: 196 Columns: 7
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (4): experience, hashedEmail, name, gender
# dbl (2): played_hours, Age
# lgl (1): subscribe
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 1535 Columns: 5
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (3): hashedEmail, start_time, end_time
# dbl (2): original_start_time, original_end_time
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
players |>
    select(where(is.numeric)) |>
    summary()
players |>
    summarise(across(where(is.numeric), ~round(mean(.x, na.rm = TRUE), 2)))
colSums(is.na(players))
# Out:
#   played_hours          Age
#  Min.   :  0.000   Min.   : 9.00
#  1st Qu.:  0.000   1st Qu.:17.00
#  Median :  0.100   Median :19.00
#  Mean   :  5.846   Mean   :21.14
#  3rd Qu.:  0.600   3rd Qu.:22.75
#  Max.   :223.100   Max.   :58.00
#                    NA's   :2
#   played_hours Age
# 1 5.85         21.14
#   experience    subscribe  hashedEmail played_hours         name       gender
#            0            0            0            0            0            0
#          Age
#            2

# %%
sessions |>
    select(where(is.numeric)) |>
    summary()
sessions |>
    summarise(across(where(is.numeric), ~round(mean(.x, na.rm = TRUE), 2)))
colSums(is.na(sessions))
# Out:
#  original_start_time original_end_time
#  Min.   :1.712e+12   Min.   :1.712e+12
#  1st Qu.:1.716e+12   1st Qu.:1.716e+12
#  Median :1.719e+12   Median :1.719e+12
#  Mean   :1.719e+12   Mean   :1.719e+12
#  3rd Qu.:1.722e+12   3rd Qu.:1.722e+12
#  Max.   :1.727e+12   Max.   :1.727e+12
#                      NA's   :2
#   original_start_time original_end_time
# 1 1.719201e+12        1.719196e+12
#         hashedEmail          start_time            end_time original_start_time
#                   0                   0                   2                   0
#   original_end_time
#                   2

# %%
ggplot(players, aes(x = played_hours)) +
    geom_histogram(binwidth =5, fill = "steelblue", color = "black")  +
    scale_x_continuous(limits = c(0, 50)) +
    scale_y_continuous(limits = c(0, 10))
    labs(title = "Distribtution of played hours", 
         x = "Played hours",
         y = "Count")
# Out:
# Warning message:
# “Removed 6 rows containing non-finite outside the scale range (`stat_bin()`).”
# Warning message:
# “Removed 2 rows containing missing values or values outside the scale range
# (`geom_bar()`).”
# $x
# [1] "Played hours"
#
# $y
# [1] "Count"
#
# $title
# [1] "Distribtution of played hours"
#
# attr(,"class")
# [1] "labels"
# plot without title

# %%
ggplot(players, aes(x = Age)) +
  geom_histogram(binwidth = 2, fill="salmon", color="black") +
  labs(title = "Distribution of Player Age", x="Age", y="Count")
# Out:
# Warning message:
# “Removed 2 rows containing non-finite outside the scale range (`stat_bin()`).”
# plot without title

# %% [raw]
# Datasets:
#     -player.csv:
#         number of observations:196
#         variables:
#             -experience(chr): Player self-reported skill level
#             -subscribe(lgl): Whether the player subscribes
#             -hashedEmail(chr): Unique player ID
#             -played_hours(dbl): Total hours played
#             -name(chr): Player name
#             -gender(chr): Player gender
#             -Age(dbl): Player age
#         Summary statistics: Shown above
#         issues:
#             -played_hours is heavily right-skewed(many casual players)
#             -two missing value in Age
#             -categorail variables may need cleaning for consistency
#             -some extreme values may be outliers
#
#     -session.csv
#         number of observations:1535
#         variables:
#             -hashedEmail(chr)
#             -start_time(dbl)
#             -end_time(dbl)
#             -original_start_time(dbl)
#             -original_end_time(dbl)
#         Summary statistics: Shown above
#         issues:
#             -timestamps may havetimezone differences
#             -there are incomplete sessions(2 NAs in end_time and original_end_times)
#             -a derivied variable could be useful: duration = end_time - start_time

# %% [raw]
# Broad Questions:
#     Can a playes's total playtime, age, and self-reported skill level predict whether they subsrcribe to the game's newsletter?
#
# Explanatory Variables:
#     -played_hours
#     -Age
#     -exprience
#
# How the data will help:
#     -player.csv contains all relevant player-level variables.
#     -sessions.csv could be joined with players.csv to derive additional metrics(session duration)
#     -These combined features can be used as predictiors in a classification model to forecast subscription likelihood.
#
# Planned Data Wrangling:
#     -Merge session.csv and player.csv using hashedEmail(kind of challeging)
#     -Compute new summary sessions from sessions.
#     -Handle missing value
